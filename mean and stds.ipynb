# %%
import pandas as pd
import numpy as np
# Read the CSV file
df = pd.read_csv('fold_results.csv',index_col="script")

df.drop(columns=['fold'], inplace=True)

means = df.groupby(["script","model"]).mean()*100
stds = df.groupby(["script","model"]).std()*100

# %%
# Rename columns in means and stds
means_renamed = means.rename(columns={'valid_accuracy': 'valid_mean', 'test_accuracy': 'test_mean'})
stds_renamed = stds.rename(columns={'valid_accuracy': 'valid_std', 'test_accuracy': 'test_std'})

# Merge means and stds on their index (script, model)
merged = means_renamed.merge(stds_renamed, left_index=True, right_index=True)
merged
# Out:
#                                                                 valid_mean  \
# script                                     model
# train.py                                   KONet                 96.170982
#                                            conv_next             96.687360
#                                            dense                 96.035923
#                                            efficient             96.334173
#                                            mobilenet             93.618475
# train_distillation.py                      conv_next             96.442721
#                                            mobilenet             94.053037
# train_distillation_other.py                conv_next             99.511164
#                                            mobilenet             98.832921
# train_incremental_early_stop.py            conv_next             90.746021
#                                            dense                 89.051849
#                                            mobilenet             86.262864
# train_incremental_ewc.py                   conv_next             86.368979
#                                            conv_next_distilled   86.050984
#                                            dense                 84.688889
#                                            mobilenet             84.033085
#                                            mobilenet_distilled   84.456829
# train_osteopenia.py                        dense_other           99.675016
# train_osteopenia_incremental.py            conv_next             80.935820
#                                            dense                 59.310431
#                                            mobilenet             81.526666
# train_osteopenia_incremental_early_stop.py conv_next             13.229573
#                                            dense                 45.758194
#                                            mobilenet             75.585482
# train_osteopenia_incremental_ewc.py        conv_next             61.180388
#                                            dense                 55.667125
#                                            mobilenet             80.629623
# train_osteopenia_incremental_lwf.py        conv_next             79.076716
#                                            dense                 63.612600
#                                            mobilenet             76.941680
# train_other.py                             KONet                 99.782903
#                                            conv_next             99.321168
#                                            dense                 99.212325
#                                            efficient             99.837251
#                                            mobilenet             99.647255
# train_other_finetune.py                    conv_next             84.860248
#                                            dense                 82.653385
#                                            mobilenet             81.917702
#
#                                                                 test_mean  \
# script                                     model
# train.py                                   KONet                94.694377
#                                            conv_next            94.718826
#                                            dense                94.841076
#                                            efficient            94.889976
#                                            mobilenet            93.251834
# train_distillation.py                      conv_next            94.449878
#                                            mobilenet            93.740831
# train_distillation_other.py                conv_next            99.608802
#                                            mobilenet            99.022005
# train_incremental_early_stop.py            conv_next            89.901460
#                                            dense                85.997273
#                                            mobilenet            84.348107
# train_incremental_ewc.py                   conv_next            85.213728
#                                            conv_next_distilled  86.003412
#                                            dense                81.275371
#                                            mobilenet            83.647230
#                                            mobilenet_distilled  84.434804
# train_osteopenia.py                        dense_other          99.634146
# train_osteopenia_incremental.py            conv_next            81.583703
#                                            dense                58.173638
#                                            mobilenet            82.831771
# train_osteopenia_incremental_early_stop.py conv_next            73.896742
#                                            dense                73.094194
#                                            mobilenet            81.301827
# train_osteopenia_incremental_ewc.py        conv_next            60.954056
#                                            dense                55.796682
#                                            mobilenet            82.127498
# train_osteopenia_incremental_lwf.py        conv_next            78.187914
#                                            dense                61.490326
#                                            mobilenet            78.371513
# train_other.py                             KONet                99.706601
#                                            conv_next            99.144254
#                                            dense                99.168704
#                                            efficient            99.731051
#                                            mobilenet            99.682152
# train_other_finetune.py                    conv_next            83.616268
#                                            dense                79.860591
#                                            mobilenet            82.074122
#
#                                                                 valid_std  \
# script                                     model
# train.py                                   KONet                 1.178732
#                                            conv_next             1.007166
#                                            dense                 1.248884
#                                            efficient             1.027667
#                                            mobilenet             2.375152
# train_distillation.py                      conv_next             1.198579
#                                            mobilenet             1.828460
# train_distillation_other.py                conv_next             0.540336
#                                            mobilenet             1.232810
# train_incremental_early_stop.py            conv_next             1.605424
#                                            dense                 1.123073
#                                            mobilenet             1.282964
# train_incremental_ewc.py                   conv_next             1.834207
#                                            conv_next_distilled   1.979941
#                                            dense                 2.294189
#                                            mobilenet             1.470119
#                                            mobilenet_distilled   1.566212
# train_osteopenia.py                        dense_other           0.378892
# train_osteopenia_incremental.py            conv_next             1.774393
#                                            dense                 5.892610
#                                            mobilenet             2.380191
# train_osteopenia_incremental_early_stop.py conv_next             4.912434
#                                            dense                 6.007637
#                                            mobilenet             3.810383
# train_osteopenia_incremental_ewc.py        conv_next            25.086965
#                                            dense                 6.104005
#                                            mobilenet             2.423008
# train_osteopenia_incremental_lwf.py        conv_next             2.392455
#                                            dense                 5.827310
#                                            mobilenet             1.678516
# train_other.py                             KONet                 0.280113
#                                            conv_next             0.759977
#                                            dense                 1.051830
#                                            efficient             0.291533
#                                            mobilenet             0.287103
# train_other_finetune.py                    conv_next             1.932460
#                                            dense                 1.934245
#                                            mobilenet             3.003115
#
#                                                                  test_std
# script                                     model
# train.py                                   KONet                 0.475919
#                                            conv_next             0.693465
#                                            dense                 0.850490
#                                            efficient             0.467470
#                                            mobilenet             1.686864
# train_distillation.py                      conv_next             0.823509
#                                            mobilenet             1.076288
# train_distillation_other.py                conv_next             0.478007
#                                            mobilenet             1.411614
# train_incremental_early_stop.py            conv_next             1.777613
#                                            dense                 0.909491
#                                            mobilenet             1.084694
# train_incremental_ewc.py                   conv_next             1.710736
#                                            conv_next_distilled   1.447373
#                                            dense                 2.950022
#                                            mobilenet             1.095320
#                                            mobilenet_distilled   1.235940
# train_osteopenia.py                        dense_other           0.385644
# train_osteopenia_incremental.py            conv_next             1.965680
#                                            dense                 7.501432
#                                            mobilenet             1.224931
# train_osteopenia_incremental_early_stop.py conv_next             1.885499
#                                            dense                 1.548367
#                                            mobilenet             1.277235
# train_osteopenia_incremental_ewc.py        conv_next            23.904526
#                                            dense                 7.357879
#                                            mobilenet             1.547975
# train_osteopenia_incremental_lwf.py        conv_next             2.913343
#                                            dense                 5.623175
#                                            mobilenet             2.316128
# train_other.py                             KONet                 0.689623
#                                            conv_next             1.159760
#                                            dense                 1.503662
#                                            efficient             0.354312
#                                            mobilenet             0.201289
# train_other_finetune.py                    conv_next             1.686944
#                                            dense                 2.118468
#                                            mobilenet             2.806527

# %%
from scipy.stats import ttest_ind

# Dictionary to store t-test results
ttest_results = {}

# Significance threshold
alpha = 0.05

# Iterate over each script
for script in df.index.unique():
    # Get models for this script
    models = df.loc[script, 'model'].unique()
    # Iterate over all pairs of models
    for i, model1 in enumerate(models):
        for model2 in models[i+1:]:
            # Get valid_accuracy for both models
            acc1 = df.loc[(script, ), :][df.loc[(script, ), :]['model'] == model1]['valid_accuracy']
            acc2 = df.loc[(script, ), :][df.loc[(script, ), :]['model'] == model2]['valid_accuracy']
            # Perform t-test
            t_stat, p_val = ttest_ind(acc1, acc2, equal_var=False)
            # Check statistical significance
            significant = p_val < alpha
            # Store result
            ttest_results[(script, model1, model2)] = {
                't_stat': t_stat,
                'p_val': p_val,
                'significant': significant
            }

ttest_results
# Out:
# {('train.py', 'mobilenet', 'efficient'): {'t_stat': -3.318384459796801,
#   'p_val': 0.005968273141131318,
#   'significant': True},
#  ('train.py', 'mobilenet', 'dense'): {'t_stat': -2.8487789977549793,
#   'p_val': 0.013169196817909238,
#   'significant': True},
#  ('train.py', 'mobilenet', 'conv_next'): {'t_stat': -3.7616869082229716,
#   'p_val': 0.002661947704820441,
#   'significant': True},
#  ('train.py', 'mobilenet', 'KONet'): {'t_stat': -3.0441486928748667,
#   'p_val': 0.009278742354672494,
#   'significant': True},
#  ('train.py', 'efficient', 'dense'): {'t_stat': 0.5831463670334186,
#   'p_val': 0.5672953147625032,
#   'significant': False},
#  ('train.py', 'efficient', 'conv_next'): {'t_stat': -0.7761918984858358,
#   'p_val': 0.44771944341727654,
#   'significant': False},
#  ('train.py', 'efficient', 'KONet'): {'t_stat': 0.32999780654078703,
#   'p_val': 0.745281346167938,
#   'significant': False},
#  ('train.py', 'dense', 'conv_next'): {'t_stat': -1.2839862722892514,
#   'p_val': 0.21614802004750477,
#   'significant': False},
#  ('train.py', 'dense', 'KONet'): {'t_stat': -0.24870178774404142,
#   'p_val': 0.8064162628921697,
#   'significant': False},
#  ('train.py', 'conv_next', 'KONet'): {'t_stat': 1.0532205069687535,
#   'p_val': 0.3065076943399144,
#   'significant': False},
#  ('train_other.py', 'mobilenet', 'efficient'): {'t_stat': -1.4683951800800792,
#   'p_val': 0.15925977393790852,
#   'significant': False},
#  ('train_other.py', 'mobilenet', 'dense'): {'t_stat': 1.2614486463204024,
#   'p_val': 0.23487906020061863,
#   'significant': False},
#  ('train_other.py', 'mobilenet', 'conv_next'): {'t_stat': 1.2692985914281019,
#   'p_val': 0.2293838032204341,
#   'significant': False},
#  ('train_other.py', 'mobilenet', 'KONet'): {'t_stat': -1.069423170649642,
#   'p_val': 0.2990195183379319,
#   'significant': False},
#  ('train_other.py', 'efficient', 'dense'): {'t_stat': 1.810553788271239,
#   'p_val': 0.09922724917134097,
#   'significant': False},
#  ('train_other.py', 'efficient', 'conv_next'): {'t_stat': 2.0049730333945552,
#   'p_val': 0.06888687037371212,
#   'significant': False},
#  ('train_other.py', 'efficient', 'KONet'): {'t_stat': 0.42509301550141004,
#   'p_val': 0.6758152891117875,
#   'significant': False},
#  ('train_other.py', 'dense', 'conv_next'): {'t_stat': -0.2652409947118844,
#   'p_val': 0.7941320641697658,
#   'significant': False},
#  ('train_other.py', 'dense', 'KONet'): {'t_stat': -1.6576437088790483,
#   'p_val': 0.12757951812804078,
#   'significant': False},
#  ('train_other.py', 'conv_next', 'KONet'): {'t_stat': -1.8027360643567019,
#   'p_val': 0.09790052395660762,
#   'significant': False},
#  ('train_distillation.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': -3.4564720819401806, 'p_val': 0.0033728634024965684, 'significant': True},
#  ('train_distillation_other.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': -1.5934277995273511, 'p_val': 0.13635386570594618, 'significant': False},
#  ('train_incremental_ewc.py',
#   'conv_next',
#   'dense'): {'t_stat': 1.808785688267813, 'p_val': 0.08803129550071079, 'significant': False},
#  ('train_incremental_ewc.py',
#   'conv_next',
#   'mobilenet'): {'t_stat': 3.142423356750152, 'p_val': 0.005878467879508156, 'significant': True},
#  ('train_incremental_ewc.py',
#   'conv_next',
#   'conv_next_distilled'): {'t_stat': 0.37258060110265523, 'p_val': 0.7138365016846415, 'significant': False},
#  ('train_incremental_ewc.py',
#   'conv_next',
#   'mobilenet_distilled'): {'t_stat': 2.507031740700863, 'p_val': 0.02224865543720828, 'significant': True},
#  ('train_incremental_ewc.py',
#   'dense',
#   'mobilenet'): {'t_stat': 0.7610941700332866, 'p_val': 0.4581530934187765, 'significant': False},
#  ('train_incremental_ewc.py',
#   'dense',
#   'conv_next_distilled'): {'t_stat': -1.4213604549178935, 'p_val': 0.17266696045907123, 'significant': False},
#  ('train_incremental_ewc.py',
#   'dense',
#   'mobilenet_distilled'): {'t_stat': 0.26417643584153716, 'p_val': 0.7950392232091961, 'significant': False},
#  ('train_incremental_ewc.py',
#   'mobilenet',
#   'conv_next_distilled'): {'t_stat': -2.587599663424363, 'p_val': 0.019415070781407622, 'significant': True},
#  ('train_incremental_ewc.py',
#   'mobilenet',
#   'mobilenet_distilled'): {'t_stat': -0.6238093122042461, 'p_val': 0.5406094266130431, 'significant': False},
#  ('train_incremental_ewc.py',
#   'conv_next_distilled',
#   'mobilenet_distilled'): {'t_stat': 1.996881543277862, 'p_val': 0.06201458333970268, 'significant': False},
#  ('train_other_finetune.py',
#   'dense',
#   'mobilenet'): {'t_stat': 0.6512768363208455, 'p_val': 0.5244860980773067, 'significant': False},
#  ('train_other_finetune.py',
#   'dense',
#   'conv_next'): {'t_stat': -2.5524026911843047, 'p_val': 0.019999044223436176, 'significant': True},
#  ('train_other_finetune.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': -2.605645700181475, 'p_val': 0.019588520699912727, 'significant': True},
#  ('train_osteopenia_incremental_ewc.py',
#   'mobilenet',
#   'dense'): {'t_stat': 12.01985003248039, 'p_val': 5.80307500815304e-08, 'significant': True},
#  ('train_osteopenia_incremental_ewc.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': 2.440271340712703, 'p_val': 0.03688431006181725, 'significant': True},
#  ('train_osteopenia_incremental_ewc.py',
#   'dense',
#   'conv_next'): {'t_stat': -0.6752603353507268, 'p_val': 0.5147279383430884, 'significant': False},
#  ('train_osteopenia_incremental_lwf.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': -2.310171715772613, 'p_val': 0.03442838405324244, 'significant': True},
#  ('train_osteopenia_incremental_lwf.py',
#   'mobilenet',
#   'dense'): {'t_stat': 6.950627826081707, 'p_val': 3.101463545274599e-05, 'significant': True},
#  ('train_osteopenia_incremental_lwf.py',
#   'conv_next',
#   'dense'): {'t_stat': 7.763036881446421, 'p_val': 5.240793872507716e-06, 'significant': True},
#  ('train_osteopenia_incremental.py',
#   'mobilenet',
#   'dense'): {'t_stat': 11.05460969024261, 'p_val': 1.3396323924587113e-07, 'significant': True},
#  ('train_osteopenia_incremental.py',
#   'mobilenet',
#   'conv_next'): {'t_stat': 0.6293505473843305, 'p_val': 0.5376636542626719, 'significant': False},
#  ('train_osteopenia_incremental.py',
#   'dense',
#   'conv_next'): {'t_stat': -11.112421380584692, 'p_val': 3.5161771088838644e-07, 'significant': True},
#  ('train_incremental_early_stop.py',
#   'conv_next',
#   'dense'): {'t_stat': 2.734429585198934, 'p_val': 0.014631516232890955, 'significant': True},
#  ('train_incremental_early_stop.py',
#   'conv_next',
#   'mobilenet'): {'t_stat': 6.89848748807212, 'p_val': 2.4458081643928563e-06, 'significant': True},
#  ('train_incremental_early_stop.py',
#   'dense',
#   'mobilenet'): {'t_stat': 5.17251833381479, 'p_val': 6.755783347802759e-05, 'significant': True},
#  ('train_osteopenia_incremental_early_stop.py',
#   'conv_next',
#   'dense'): {'t_stat': -13.255067282592771, 'p_val': 1.6911615952247606e-10, 'significant': True},
#  ('train_osteopenia_incremental_early_stop.py',
#   'conv_next',
#   'mobilenet'): {'t_stat': -31.717366371550966, 'p_val': 1.555766479352112e-16, 'significant': True},
#  ('train_osteopenia_incremental_early_stop.py',
#   'dense',
#   'mobilenet'): {'t_stat': -13.258442479412112, 'p_val': 9.002544964234015e-10, 'significant': True}}

# %%
# Find models common to both train.py and train_distillation.py
scripts_of_interest = ['train.py', 'train_distillation.py']
models_train = set(df.loc[scripts_of_interest[0], 'model'].unique())
models_distill = set(df.loc[scripts_of_interest[1], 'model'].unique())
common_models = models_train.intersection(models_distill)

# Dictionary to store t-test results for common models
ttest_common = {}

for model in common_models:
    acc_train = df.loc[(scripts_of_interest[0]), :][df.loc[(scripts_of_interest[0]), :]['model'] == model]['valid_accuracy']
    acc_distill = df.loc[(scripts_of_interest[1]), :][df.loc[(scripts_of_interest[1]), :]['model'] == model]['valid_accuracy']
    t_stat, p_val = ttest_ind(acc_train, acc_distill, equal_var=False)
    significant = p_val < alpha
    ttest_common[model] = {
        't_stat': t_stat,
        'p_val': p_val,
        'significant': significant
    }
ttest_common
# Out:
# {'conv_next': {'t_stat': 0.494146825549851,
#   'p_val': 0.6273543360528215,
#   'significant': False},
#  'mobilenet': {'t_stat': -0.4584602571433014,
#   'p_val': 0.6524642423571612,
#   'significant': False}}

# %%
# Find models common to both train.py and train_distillation.py
scripts_of_interest = ['train_other.py', 'train_distillation_other.py']
models_train = set(df.loc[scripts_of_interest[0], 'model'].unique())
models_distill = set(df.loc[scripts_of_interest[1], 'model'].unique())
common_models = models_train.intersection(models_distill)

# Dictionary to store t-test results for common models
ttest_common = {}

for model in common_models:
    acc_train = df.loc[(scripts_of_interest[0]), :][df.loc[(scripts_of_interest[0]), :]['model'] == model]['valid_accuracy']
    acc_distill = df.loc[(scripts_of_interest[1]), :][df.loc[(scripts_of_interest[1]), :]['model'] == model]['valid_accuracy']
    t_stat, p_val = ttest_ind(acc_train, acc_distill, equal_var=False)
    significant = p_val < alpha
    ttest_common[model] = {
        't_stat': t_stat,
        'p_val': p_val,
        'significant': significant
    }
ttest_common
# Out:
# {'conv_next': {'t_stat': -0.6443232522043958,
#   'p_val': 0.5283584265214332,
#   'significant': False},
#  'mobilenet': {'t_stat': 2.0344056249231786,
#   'p_val': 0.06936747379891674,
#   'significant': False}}

# %%
# Find models common to both train.py and train_distillation.py
scripts_of_interest = ['train_incremental_ewc.py', 'train_incremental_early_stop.py']
models_train = set(df.loc[scripts_of_interest[0], 'model'].unique())
models_distill = set(df.loc[scripts_of_interest[1], 'model'].unique())
common_models = models_train.intersection(models_distill)

# Dictionary to store t-test results for common models
ttest_common = {}

for model in common_models:
    acc_train = df.loc[(scripts_of_interest[0]), :][df.loc[(scripts_of_interest[0]), :]['model'] == model]['valid_accuracy']
    acc_distill = df.loc[(scripts_of_interest[1]), :][df.loc[(scripts_of_interest[1]), :]['model'] == model]['valid_accuracy']
    t_stat, p_val = ttest_ind(acc_train, acc_distill, equal_var=False)
    significant = p_val < alpha
    ttest_common[model] = {
        't_stat': t_stat,
        'p_val': p_val,
        'significant': significant
    }
ttest_common
# Out:
# {'dense': {'t_stat': -5.4013757277156484,
#   'p_val': 0.00011832536373437486,
#   'significant': True},
#  'conv_next': {'t_stat': -5.678392235061869,
#   'p_val': 2.3406923342070926e-05,
#   'significant': True},
#  'mobilenet': {'t_stat': -3.6137356144056594,
#   'p_val': 0.002034171917254026,
#   'significant': True}}
